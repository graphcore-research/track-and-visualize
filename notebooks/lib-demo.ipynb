# %%
import os
import sys
# add local lib to sys path for relative import
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from src.log import TensorType, LogFrame
from src import transform
from src import vis


# load DF as a log frame
lf = LogFrame.from_pickle('../test-data/numerics_df_v2.pkl')

# transform it to the appropriate 'view' for visualisation
mv = transform.to_master_view(
    lf=lf,
    tt=TensorType.Activation,
    inc=50,
    scalar_metric='rm4')

# visualise
vis.global_view(mv, figsize=(21,10))
